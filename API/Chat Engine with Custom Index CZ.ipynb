# %%
import os
    
# add your openai api key here
os.environ['OPENAI_API_KEY'] = 'sk-xx'

# %%
from llama_index import VectorStoreIndex, SimpleDirectoryReader, ServiceContext
from llama_index.llms import OpenAI

# Necessary to use the latest OpenAI models that support function calling API
service_context = ServiceContext.from_defaults(llm=OpenAI(model="gpt-3.5-turbo-0613"))
data = SimpleDirectoryReader(input_dir="./data/cs/zeman").load_data()
index = VectorStoreIndex.from_documents(data, service_context=service_context)

# %%
chat_engine = index.as_chat_engine(
    chat_mode='openai',
    verbose=False, 
    system_prompt = "You should answer in Czech"
)

# %%
chat_engine = index.as_chat_engine(chat_mode="openai", verbose=True)

# %%
response = chat_engine.chat('Jaka je názor na téma, zda je Zeman lhář?')
print(response)
# Out:
# Jako virtuální asistent nemám vlastní názory. Nicméně, názor na to, zda je Miloš Zeman lhář, je subjektivní a závisí na osobním hodnocení jednotlivce. Někteří lidé mohou mít pocit, že Miloš Zeman lže, zatímco jiní ho mohou považovat za důvěryhodného. Je důležité provádět vlastní výzkum a posuzovat informace z různých zdrojů, abyste si udělali vlastní názor na toto téma.

# %%
response = chat_engine.chat('Jaka je názor na téma, zda je Zeman lhář?', function_call="query_engine_tool")
print(response)
# Out:
# === Calling Function ===
# Calling function: query_engine_tool with args: {
#   "input": "Názor na to, zda je Miloš Zeman lhář"
# }
# Got output: Miloš Zeman's honesty is a matter of opinion and can vary among individuals. Some people may consider him to be a liar, while others may not.
# ...
# === Calling Function ===
# Calling function: query_engine_tool with args: {
#   "input": "Názor na to, zda je Miloš Zeman lhář"
# }
# Got output: Miloš Zeman's honesty is a matter of opinion and can vary among individuals. Some people may believe that he is a liar, while others may not share this view. It is important to note that opinions on this matter can be influenced by various factors, such as personal beliefs, political affiliations, and media portrayal.
# ...
# === Calling Function ===
# Calling function: query_engine_tool with args: {
#   "input": "Názor na to, zda je Miloš Zeman lhář"
# }
# ...
